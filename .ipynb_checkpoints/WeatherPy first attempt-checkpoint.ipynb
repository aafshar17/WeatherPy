# %%
import matplotlib.pyplot as plt
import requests as req
import pandas as pd

# %%
# Save config information.
lat = '55.5'
url = "http://api.openweathermap.org/data/2.5/find?"
lon = '37.5'
cnt = '1'
api_key = '0d632d3554840214b23b57727985763e'


# Build partial query URL
query_url = url + "APPID=" + api_key + "&lat=" + lat + "&lon=" + lon + "&cnt=" + cnt

# %%
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/find?APPID=0d632d3554840214b23b57727985763e&lat=55.5&lon=37.5&cnt=1'

# %%
response = req.get(query_url).json()
set_cities_one = response
set_cities_one
# Out:
# {'cod': '200',
#  'count': 1,
#  'list': [{'clouds': {'all': 40},
#    'coord': {'lat': 55.4997, 'lon': 37.5597},
#    'dt': 1521174600,
#    'id': 495260,
#    'main': {'humidity': 66,
#     'pressure': 1012,
#     'temp': 261.39,
#     'temp_max': 263.15,
#     'temp_min': 260.15},
#    'name': 'Shcherbinka',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03d',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 320, 'speed': 4}}],
#  'message': 'accurate'}

# %%
city_one_lat = set_cities_one['list'][0]['coord']['lat']
city_one_lat
# Out:
# 55.4997

# %%
city_one_temp = set_cities_one['list'][0]['main']['temp']
city_one_temp
# Out:
# 261.39

# %%
city_one_hum_percent = set_cities_one['list'][0]['main']['humidity']
city_one_hum_percent
# Out:
# 66

# %%
city_one_cloud_percent = set_cities_one['list'][0]['clouds']['all']
city_one_cloud_percent
# Out:
# 40

# %%
city_one_wind_speed = set_cities_one['list'][0]['wind']['speed']
city_one_wind_speed
# Out:
# 4

# %%
listdicts = response['list']
listdicts
# Out:
# [{'clouds': {'all': 75},
#   'coord': {'lat': 55.4997, 'lon': 37.5597},
#   'dt': 1521171000,
#   'id': 495260,
#   'main': {'humidity': 66,
#    'pressure': 1011,
#    'temp': 261.88,
#    'temp_max': 263.15,
#    'temp_min': 260.15},
#   'name': 'Shcherbinka',
#   'rain': None,
#   'snow': None,
#   'sys': {'country': ''},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 340, 'speed': 5}},
#  {'clouds': {'all': 75},
#   'coord': {'lat': 55.4397, 'lon': 37.4867},
#   'dt': 1521171000,
#   'id': 564517,
#   'main': {'humidity': 66,
#    'pressure': 1011,
#    'temp': 261.88,
#    'temp_max': 263.15,
#    'temp_min': 260.15},
#   'name': 'Dubrovitsy',
#   'rain': None,
#   'snow': None,
#   'sys': {'country': ''},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 340, 'speed': 5}},
#  {'clouds': {'all': 75},
# ...

# %%
citynamedict = listdicts[15]['name']
citynamedict
# Out:
# 'Solnechnyy'

# %%
# Save config information.
lat = '37.08'
url = "http://api.openweathermap.org/data/2.5/find?"
lon = '14.56'
cnt = '50'
api_key = '0d632d3554840214b23b57727985763e'


# Build partial query URL
query_url = url + "APPID=" + api_key + "&lat=" + lat + "&lon=" + lon + "&cnt=" + cnt
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/find?APPID=0d632d3554840214b23b57727985763e&lat=37.08&lon=14.56&cnt=50'

# %%
response = req.get(query_url).json()
set_cities_two = response
set_cities_two
# Out:
# {'cod': '200',
#  'count': 50,
#  'list': [{'clouds': {'all': 40},
#    'coord': {'lat': 37.0883, 'lon': 14.5613},
#    'dt': 1521161700,
#    'id': 6535329,
#    'main': {'humidity': 100,
#     'pressure': 1011,
#     'temp': 284.68,
#     'temp_max': 285.15,
#     'temp_min': 284.15},
#    'name': 'Mazzarrone',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03n',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 168.503, 'speed': 1.47}},
#   {'clouds': {'all': 40},
#    'coord': {'lat': 37.1, 'lon': 14.5},
#    'dt': 1521161700,
#    'id': 2523396,
#    'main': {'humidity': 100,
#     'pressure': 1011,
#     'temp': 284.68,
#     'temp_max': 285.15,
#     'temp_min': 284.15},
#    'name': 'San Pietro',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03n',
#      'id': 802,
# ...

# %%
# Save config information.
lat = '-20.93'
url = "http://api.openweathermap.org/data/2.5/find?"
lon = '29.00'
cnt = '50'
api_key = '0d632d3554840214b23b57727985763e'


# Build partial query URL
query_url = url + "APPID=" + api_key + "&lat=" + lat + "&lon=" + lon + "&cnt=" + cnt
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/find?APPID=0d632d3554840214b23b57727985763e&lat=-20.93&lon=29.00&cnt=50'

# %%
response = req.get(query_url).json()
set_cities_three = response
set_cities_three
# Out:
# {'cod': '200',
#  'count': 12,
#  'list': [{'clouds': {'all': 0},
#    'coord': {'lat': -20.9334, 'lon': 29},
#    'dt': 1521164023,
#    'id': 890516,
#    'main': {'grnd_level': 913.51,
#     'humidity': 78,
#     'pressure': 913.51,
#     'sea_level': 1022.78,
#     'temp': 289.378,
#     'temp_max': 289.378,
#     'temp_min': 289.378},
#    'name': 'Gwanda',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'Sky is Clear',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 31.5034, 'speed': 1.27}},
#   {'clouds': {'all': 0},
#    'coord': {'lat': -20.5334, 'lon': 29.285},
#    'dt': 1521164023,
#    'id': 891515,
#    'main': {'grnd_level': 896.33,
#     'humidity': 81,
#     'pressure': 896.33,
#     'sea_level': 1023.31,
#     'temp': 287.628,
#     'temp_max': 287.628,
#     'temp_min': 287.628},
#    'name': 'Filabusi',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
# ...

# %%
# Save config information.
lat = '42.27'
url = "http://api.openweathermap.org/data/2.5/find?"
lon = '-122.82'
cnt = '50'
api_key = '0d632d3554840214b23b57727985763e'


# Build partial query URL
query_url = url + "APPID=" + api_key + "&lat=" + lat + "&lon=" + lon + "&cnt=" + cnt
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/find?APPID=0d632d3554840214b23b57727985763e&lat=42.27&lon=-122.82&cnt=50'

# %%
response = req.get(query_url).json()
set_cities_four = response
set_cities_four
# Out:
# {'cod': '200',
#  'count': 50,
#  'list': [{'clouds': {'all': 90},
#    'coord': {'lat': 42.2754, 'lon': -122.8181},
#    'dt': 1521161760,
#    'id': 5745656,
#    'main': {'humidity': 81,
#     'pressure': 1006,
#     'temp': 275.35,
#     'temp_max': 279.15,
#     'temp_min': 271.15},
#    'name': 'Phoenix',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'light rain',
#      'icon': '10n',
#      'id': 500,
#      'main': 'Rain'},
#     {'description': 'fog', 'icon': '50n', 'id': 741, 'main': 'Fog'}],
#    'wind': {'deg': 280, 'speed': 4.1}},
#   {'clouds': {'all': 90},
#    'coord': {'lat': 42.2457, 'lon': -122.7887},
#    'dt': 1521161760,
#    'id': 5755890,
#    'main': {'humidity': 81,
#     'pressure': 1006,
#     'temp': 275.34,
#     'temp_max': 279.15,
#     'temp_min': 271.15},
#    'name': 'Talent',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'light rain',
# ...

# %%
# Save config information.
lat = '-22.71'
url = "http://api.openweathermap.org/data/2.5/find?"
lon = '-42.61'
cnt = '50'
api_key = '0d632d3554840214b23b57727985763e'


# Build partial query URL
query_url = url + "APPID=" + api_key + "&lat=" + lat + "&lon=" + lon + "&cnt=" + cnt
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/find?APPID=0d632d3554840214b23b57727985763e&lat=-22.71&lon=-42.61&cnt=50'

# %%
response = req.get(query_url).json()
set_cities_five = response
set_cities_five
# Out:
# {'cod': '200',
#  'count': 50,
#  'list': [{'clouds': {'all': 0},
#    'coord': {'lat': -22.7087, 'lon': -42.6098},
#    'dt': 1521162000,
#    'id': 3451261,
#    'main': {'humidity': 88,
#     'pressure': 1011,
#     'temp': 302.5,
#     'temp_max': 304.15,
#     'temp_min': 300.15},
#    'name': 'Rio Bonito',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'Sky is Clear',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 50, 'speed': 3.6}},
#   {'clouds': {'all': 0},
#    'coord': {'lat': -22.7303, 'lon': -42.7142},
#    'dt': 1521162000,
#    'id': 3446974,
#    'main': {'humidity': 84,
#     'pressure': 1010,
#     'temp': 302.46,
#     'temp_max': 304.15,
#     'temp_min': 300.15},
#    'name': 'Tangua',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'Sky is Clear',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
# ...

# %%
# Save config information.
lat = '-33.87'
url = "http://api.openweathermap.org/data/2.5/find?"
lon = '151.21'
cnt = '50'
api_key = '0d632d3554840214b23b57727985763e'


# Build partial query URL
query_url = url + "APPID=" + api_key + "&lat=" + lat + "&lon=" + lon + "&cnt=" + cnt
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/find?APPID=0d632d3554840214b23b57727985763e&lat=-33.87&lon=151.21&cnt=50'

# %%
response = req.get(query_url).json()
set_cities_six = response
set_cities_six
# Out:
# {'cod': '200',
#  'count': 50,
#  'list': [{'clouds': {'all': 75},
#    'coord': {'lat': -33.8678, 'lon': 151.2084},
#    'dt': 1521162000,
#    'id': 6619279,
#    'main': {'humidity': 61,
#     'pressure': 1017,
#     'temp': 297.6,
#     'temp_max': 298.15,
#     'temp_min': 297.15},
#    'name': 'City of Sydney',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'broken clouds',
#      'icon': '04d',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 150, 'speed': 4.6}},
#   {'clouds': {'all': 75},
#    'coord': {'lat': -33.8679, 'lon': 151.2073},
#    'dt': 1521162000,
#    'id': 2147714,
#    'main': {'humidity': 61,
#     'pressure': 1017,
#     'temp': 297.6,
#     'temp_max': 298.15,
#     'temp_min': 297.15},
#    'name': 'Sydney',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'broken clouds',
#      'icon': '04d',
#      'id': 803,
# ...

# %%
# Save config information.
lat = '64.14'
url = "http://api.openweathermap.org/data/2.5/find?"
lon = '-21.90'
cnt = '50'
api_key = '0d632d3554840214b23b57727985763e'


# Build partial query URL
query_url = url + "APPID=" + api_key + "&lat=" + lat + "&lon=" + lon + "&cnt=" + cnt
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/find?APPID=0d632d3554840214b23b57727985763e&lat=64.14&lon=-21.90&cnt=50'

# %%
response = req.get(query_url).json()
set_cities_seven = response
set_cities_seven
# Out:
# {'cod': '200',
#  'count': 31,
#  'list': [{'clouds': {'all': 75},
#    'coord': {'lat': 64.1355, 'lon': -21.8955},
#    'dt': 1521163800,
#    'id': 3413829,
#    'main': {'humidity': 81,
#     'pressure': 996,
#     'temp': 279.15,
#     'temp_max': 279.15,
#     'temp_min': 279.15},
#    'name': 'Reykjavik',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'light intensity drizzle',
#      'icon': '09n',
#      'id': 300,
#      'main': 'Drizzle'}],
#    'wind': {'deg': 90, 'speed': 8.2}},
#   {'clouds': {'all': 75},
#    'coord': {'lat': 64.139, 'lon': -21.9568},
#    'dt': 1521163800,
#    'id': 3416900,
#    'main': {'humidity': 81,
#     'pressure': 996,
#     'temp': 279.15,
#     'temp_max': 279.15,
#     'temp_min': 279.15},
#    'name': 'Grímsstaðaholt',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'light intensity drizzle',
#      'icon': '09n',
#      'id': 300,
# ...

# %%
# Save config information.
lat = '15.54'
url = "http://api.openweathermap.org/data/2.5/find?"
lon = '121.09'
cnt = '50'
api_key = '0d632d3554840214b23b57727985763e'

# Build partial query URL
query_url = url + "APPID=" + api_key + "&lat=" + lat + "&lon=" + lon + "&cnt=" + cnt
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/find?APPID=0d632d3554840214b23b57727985763e&lat=15.54&lon=121.09&cnt=50'

# %%
response = req.get(query_url).json()
set_cities_eight = response
set_cities_eight
# Out:
# {'cod': '200',
#  'count': 50,
#  'list': [{'clouds': {'all': 40},
#    'coord': {'lat': 15.5414, 'lon': 121.0861},
#    'dt': 1521162000,
#    'id': 1696165,
#    'main': {'humidity': 69,
#     'pressure': 1016,
#     'temp': 301.15,
#     'temp_max': 301.15,
#     'temp_min': 301.15},
#    'name': 'Palayan City',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03d',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 360, 'speed': 4.1}},
#   {'clouds': {'all': 40},
#    'coord': {'lat': 15.55, 'lon': 121.0833},
#    'dt': 1521162000,
#    'id': 1696164,
#    'main': {'humidity': 69,
#     'pressure': 1016,
#     'temp': 301.15,
#     'temp_max': 301.15,
#     'temp_min': 301.15},
#    'name': 'Palayan City',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03d',
#      'id': 802,
# ...

# %%
# Save config information.
lat = '35.69'
url = "http://api.openweathermap.org/data/2.5/find?"
lon = '51.42'
cnt = '50'
api_key = '0d632d3554840214b23b57727985763e'

# Build partial query URL
query_url = url + "APPID=" + api_key + "&lat=" + lat + "&lon=" + lon + "&cnt=" + cnt
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/find?APPID=0d632d3554840214b23b57727985763e&lat=35.69&lon=51.42&cnt=50'

# %%
response = req.get(query_url).json()
set_cities_nine = response
set_cities_nine
# Out:
# {'cod': '200',
#  'count': 38,
#  'list': [{'clouds': {'all': 0},
#    'coord': {'lat': 35.6944, 'lon': 51.4215},
#    'dt': 1521163800,
#    'id': 112931,
#    'main': {'humidity': 26,
#     'pressure': 1014,
#     'temp': 286.35,
#     'temp_max': 288.15,
#     'temp_min': 285.15},
#    'name': 'Tehran',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'Sky is Clear',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 340, 'speed': 3.1}},
#   {'clouds': {'all': 0},
#    'coord': {'lat': 35.6667, 'lon': 51.4167},
#    'dt': 1521163800,
#    'id': 110791,
#    'main': {'humidity': 26,
#     'pressure': 1014,
#     'temp': 286.36,
#     'temp_max': 288.15,
#     'temp_min': 285.15},
#    'name': 'Ostān-e Tehrān',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'Sky is Clear',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
# ...

# %%
# Save config information.
lat = '36.75'
url = "http://api.openweathermap.org/data/2.5/find?"
lon = '3.04'
cnt = '50'
api_key = '0d632d3554840214b23b57727985763e'

# Build partial query URL
query_url = url + "APPID=" + api_key + "&lat=" + lat + "&lon=" + lon + "&cnt=" + cnt
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/find?APPID=0d632d3554840214b23b57727985763e&lat=36.75&lon=3.04&cnt=50'

# %%
response = req.get(query_url).json()
set_cities_ten = response
set_cities_ten
# Out:
# {'cod': '200',
#  'count': 50,
#  'list': [{'clouds': {'all': 20},
#    'coord': {'lat': 36.7525, 'lon': 3.042},
#    'dt': 1521163800,
#    'id': 2507480,
#    'main': {'humidity': 100,
#     'pressure': 1008,
#     'temp': 285.15,
#     'temp_max': 285.15,
#     'temp_min': 285.15},
#    'name': 'Algiers',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'few clouds',
#      'icon': '02n',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 190, 'speed': 0.5}},
#   {'clouds': {'all': 20},
#    'coord': {'lat': 36.7458, 'lon': 3.0392},
#    'dt': 1521163800,
#    'id': 2497460,
#    'main': {'humidity': 100,
#     'pressure': 1008,
#     'temp': 285.15,
#     'temp_max': 285.15,
#     'temp_min': 285.15},
#    'name': 'Bir Mourad Raïs',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'few clouds',
#      'icon': '02n',
#      'id': 801,
#      'main': 'Clouds'}],
# ...

# %%
# Save config information.
lat = '43.70'
url = "http://api.openweathermap.org/data/2.5/find?"
lon = '-79.42'
cnt = '50'
api_key = '0d632d3554840214b23b57727985763e'

# Build partial query URL
query_url = url + "APPID=" + api_key + "&lat=" + lat + "&lon=" + lon + "&cnt=" + cnt
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/find?APPID=0d632d3554840214b23b57727985763e&lat=43.70&lon=-79.42&cnt=50'

# %%
response = req.get(query_url).json()
set_cities_eleven = response
set_cities_eleven
# Out:
# {'cod': '200',
#  'count': 50,
#  'list': [{'clouds': {'all': 75},
#    'coord': {'lat': 43.7001, 'lon': -79.4163},
#    'dt': 1521162000,
#    'id': 6167865,
#    'main': {'humidity': 74,
#     'pressure': 1006,
#     'temp': 271.97,
#     'temp_max': 273.15,
#     'temp_min': 271.15},
#    'name': 'Toronto',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'light shower snow',
#      'icon': '13n',
#      'id': 620,
#      'main': 'Snow'}],
#    'wind': {'deg': 330, 'gust': 10.8, 'speed': 7.7}},
#   {'clouds': {'all': 75},
#    'coord': {'lat': 43.6687, 'lon': -79.4167},
#    'dt': 1521162000,
#    'id': 7870922,
#    'main': {'humidity': 74,
#     'pressure': 1006,
#     'temp': 272,
#     'temp_max': 273.15,
#     'temp_min': 271.15},
#    'name': 'Seaton Village',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'light shower snow',
#      'icon': '13n',
#      'id': 620,
# ...

# %%
# Save config information.
lat = '35.69'
url = "http://api.openweathermap.org/data/2.5/find?"
lon = '139.69'
cnt = '50'
api_key = '0d632d3554840214b23b57727985763e'

# Build partial query URL
query_url = url + "APPID=" + api_key + "&lat=" + lat + "&lon=" + lon + "&cnt=" + cnt
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/find?APPID=0d632d3554840214b23b57727985763e&lat=35.69&lon=139.69&cnt=50'

# %%
response = req.get(query_url).json()
set_cities_twelve = response
set_cities_twelve
# Out:
# {'cod': '200',
#  'count': 50,
#  'list': [{'clouds': {'all': 75},
#    'coord': {'lat': 35.6895, 'lon': 139.6917},
#    'dt': 1521163800,
#    'id': 1850144,
#    'main': {'humidity': 82,
#     'pressure': 1008,
#     'temp': 289.15,
#     'temp_max': 290.15,
#     'temp_min': 288.15},
#    'name': 'Tōkyō-to',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'light intensity shower rain',
#      'icon': '09d',
#      'id': 520,
#      'main': 'Rain'}],
#    'wind': {'deg': 210, 'speed': 9.8}},
#   {'clouds': {'all': 75},
#    'coord': {'lat': 35.6895, 'lon': 139.6917},
#    'dt': 1521163800,
#    'id': 1850147,
#    'main': {'humidity': 82,
#     'pressure': 1008,
#     'temp': 289.15,
#     'temp_max': 290.15,
#     'temp_min': 288.15},
#    'name': 'Tokyo',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'light intensity shower rain',
#      'icon': '09d',
#      'id': 520,
# ...

# %%
# Save config information.
lat = '10.13'
url = "http://api.openweathermap.org/data/2.5/find?"
lon = '-64.70'
cnt = '50'
api_key = '0d632d3554840214b23b57727985763e'

# Build partial query URL
query_url = url + "APPID=" + api_key + "&lat=" + lat + "&lon=" + lon + "&cnt=" + cnt
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/find?APPID=0d632d3554840214b23b57727985763e&lat=10.13&lon=-64.70&cnt=50'

# %%
response = req.get(query_url).json()
set_cities_thirteen = response
set_cities_thirteen
# Out:
# {'cod': '200',
#  'count': 50,
#  'list': [{'clouds': {'all': 0},
#    'coord': {'lat': 10.1333, 'lon': -64.7},
#    'dt': 1521167325,
#    'id': 3648559,
#    'main': {'grnd_level': 1021.56,
#     'humidity': 96,
#     'pressure': 1021.56,
#     'sea_level': 1025.86,
#     'temp': 299.128,
#     'temp_max': 299.128,
#     'temp_min': 299.128},
#    'name': 'Barcelona',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'Sky is Clear',
#      'icon': '01n',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 51.0034, 'speed': 5.87}},
#   {'clouds': {'all': 0},
#    'coord': {'lat': 10.1209, 'lon': -64.6758},
#    'dt': 1521167364,
#    'id': 3486337,
#    'main': {'grnd_level': 1021.56,
#     'humidity': 96,
#     'pressure': 1021.56,
#     'sea_level': 1025.86,
#     'temp': 299.128,
#     'temp_max': 299.128,
#     'temp_min': 299.128},
#    'name': 'Barrio Aduana',
#    'rain': None,
#    'snow': None,
# ...

# %%
# Save config information.
lat = '13.75'
url = "http://api.openweathermap.org/data/2.5/find?"
lon = '100.52'
cnt = '50'
api_key = '0d632d3554840214b23b57727985763e'

# Build partial query URL
query_url = url + "APPID=" + api_key + "&lat=" + lat + "&lon=" + lon + "&cnt=" + cnt
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/find?APPID=0d632d3554840214b23b57727985763e&lat=13.75&lon=100.52&cnt=50'

# %%
response = req.get(query_url).json()
set_cities_fourteen = response
set_cities_fourteen
# Out:
# {'cod': '200',
#  'count': 50,
#  'list': [{'clouds': {'all': 20},
#    'coord': {'lat': 13.75, 'lon': 100.5167},
#    'dt': 1521165600,
#    'id': 1609350,
#    'main': {'humidity': 83,
#     'pressure': 1012,
#     'temp': 301.66,
#     'temp_max': 302.15,
#     'temp_min': 301.15},
#    'name': 'Bangkok',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'few clouds',
#      'icon': '02d',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 130, 'speed': 2.1}},
#   {'clouds': {'all': 20},
#    'coord': {'lat': 13.7582, 'lon': 100.5133},
#    'dt': 1521165600,
#    'id': 1607327,
#    'main': {'humidity': 83,
#     'pressure': 1012,
#     'temp': 301.66,
#     'temp_max': 302.15,
#     'temp_min': 301.15},
#    'name': 'Pom Prap Sattru Phai',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'few clouds',
#      'icon': '02d',
#      'id': 801,
# ...

# %%
set_cities_fourteen['count']
# Out:
# 50

# %% [markdown]
# # Generate the city list

# %%
lat_list = ['55.5', '37.08', '-20.93', '42.27', '-22.71', '-33.87', '64.14', '15.54', '35.69', '36.75', '43.70', '35.69', '10.13', '13.75']
lon_list = ['37.5', '14.56', '29.00', '-122.82', '-42.61', '151.21', '-21.90', '121.09', '51.42', '3.04', '-79.42', '139.69', '-64.70', '100.52']
total_count = 0

for index in range(len(lat_list)):
    lat = lat_list[index]
    url = "http://api.openweathermap.org/data/2.5/find?"
    lon = lon_list[index]
    cnt = '50'
    api_key = '0d632d3554840214b23b57727985763e'

    # Build partial query URL
    query_url = url + "APPID=" + api_key + "&lat=" + lat + "&lon=" + lon + "&cnt=" + cnt
    query_url
    
    response = req.get(query_url).json()
    set_cities = response
    total_count = total_count + set_cities['count']
    
total_count
# Out:
# 631

# %%
set_cities
# Out:
# {'cod': '200',
#  'count': 50,
#  'list': [{'clouds': {'all': 20},
#    'coord': {'lat': 13.75, 'lon': 100.5167},
#    'dt': 1521216000,
#    'id': 1609350,
#    'main': {'humidity': 83,
#     'pressure': 1011,
#     'temp': 300.64,
#     'temp_max': 301.15,
#     'temp_min': 300.15},
#    'name': 'Bangkok',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'few clouds',
#      'icon': '02n',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 190, 'speed': 4.6}},
#   {'clouds': {'all': 20},
#    'coord': {'lat': 13.7582, 'lon': 100.5133},
#    'dt': 1521216000,
#    'id': 1607327,
#    'main': {'humidity': 83,
#     'pressure': 1011,
#     'temp': 300.64,
#     'temp_max': 301.15,
#     'temp_min': 300.15},
#    'name': 'Pom Prap Sattru Phai',
#    'rain': None,
#    'snow': None,
#    'sys': {'country': ''},
#    'weather': [{'description': 'few clouds',
#      'icon': '02n',
#      'id': 801,
# ...

# %% [markdown]
# # Perform API calls

# %%
for city in set_cities:
    city_latitude = set_cities['list'][0]['coord']['lat']
    city_temp = set_cities['list'][0]['main']['temp']
    city_hum_percent = set_cities['list'][0]['main']['humidity']
    city_cloud_percent = set_cities['list'][0]['Clouds']['all']
    city_wind_speed = set_cities['list'][10]['speed']
    city_name = set_cities['list'][0]['name']
